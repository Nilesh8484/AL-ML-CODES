# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [1,2,3,4]
y= [5,6,7,8]

# %%
plt.plot(x,y)     #line plot
plt.show()

# %%
1

# Real data

# Oscar Winner Movies
oscar_movies = [
"The Dark Knight",
"The Hurt Locker",
"The King's Speech",
"The Artist",
"Argo"
]
years = [2008, 2009, 2010, 2011, 2012]
oscar_revenue = [1005, 170, 427, 133, 232]

# %%
plt.title("oscar revenue movie data in each years")
plt.plot(years,oscar_revenue)
plt.xlabel("years")
plt.ylabel("revenue (in $M")

plt.show()

# %%
# Non-Oscar Winner Movies
non_oscar_movies = ["Slumdog Millionaire","Avatar", "Inception", "Hugo","Lincoln"]

non_oscar_revenue = [378, 2788, 829, 185, 275] # in $M

# %%
plt.title("oscar movie vs non oscar movie revenue grap")
plt.plot(years,oscar_revenue , label= "oscar winner")
plt.plot(years,non_oscar_revenue, label = "non oscar winner")

plt.xlabel("years")
plt.ylabel("revenue (in $M")

plt.legend()

# %%
# Oscar Winner Movies
oscar_movies = [
"The Dark Knight",
"The Hurt Locker",
"The King's Speech",
"The Artist",
"Argo"]

years = [2008, 2009, 2010, 2011, 2012]
oscar_revenue = [1005, 170, 427, 133, 232]

# %%
plt.title("oscar movie revenue")
plt.bar(years, oscar_revenue, color = "yellow")
plt.xlabel("years")
plt.ylabel("revenue")



for i in range(len(years)):
    plt.text(years[i],oscar_revenue[i]+10, str(oscar_revenue[i]), ha="center")
plt.ylim(0,max(oscar_revenue)+150)
# Out:
# (0.0, 1155.0)

# %%
oscar_movies= [
"The Dark Knight",
"The Hurt Locker",
"The King's Speech",
"The Artist",
"Argo"
]

oscar_revenue = [1005, 170, 427, 133, 232]

non_oscar_movies = ["Slumdog Millionaire","Avatar", "Inception", "Hugo","Lincoln"]

non_oscar_revenue = [378, 2788, 829, 185, 275] # in $M
years = [2008, 2009, 2010, 2011, 2012]





# plt.title("oscar vs non_oscar movie graph")
# plt.xlabel("years")
# plt.ylabel("revenue")



x = np.arange(len(years))
width = 0.4

plt.bar(x-width/2,oscar_revenue,width,label="oscar movies")
plt.bar(x+width/2,non_oscar_revenue, width,label="non_oscar movies")
plt.title("oscar vs non_oscar movie graph")
plt.xlabel("years")
plt.ylabel("revenue")

plt.legend()
plt.xticks(x,years)
# Out:
# ([<matplotlib.axis.XTick at 0x19eee379d10>,
# ...
#  [Text(0, 0, '2008'),
#   Text(1, 0, '2009'),
#   Text(2, 0, '2010'),
#   Text(3, 0, '2011'),
#   Text(4, 0, '2012')])

# %%
oscar_movies = [
"The Dark Knight",
"The Hurt Locker",
"The King's Speech",
"The Artist",
"Argo"
]
years = [2008, 2009, 2010, 2011, 2012]
oscar_revenue = [1005, 170, 427, 133, 232]

# %%
plt.barh(oscar_movies, oscar_revenue)

plt.title("horizontal char")
plt.xlabel("revenue")
plt.ylabel("movie name")
# Out:
# Text(0, 0.5, 'movie name')

# %%
# Scatter Plots

people = ["Person A", "Person B", "Person C", "Person D", "Person E",
"Person F", "Person G", "Person H", "Person I", "Person J"]
age = [22, 25, 30, 35, 40, 45, 50, 55, 60, 65]
bp= [110, 115, 120, 122, 125, 130, 135, 123, 145, 150]

# %%
# colors= [ "green" if x < 135 else "red" for x in bp]
# plt.scatter(age,bp, color = colors , s=bp,  marker = "o", alpha = 0.7)
plt.scatter(age,bp, cmap= "OrRd"  , c= bp )
plt.title("bp value major")
plt.xlabel("age value")
plt.ylabel("bp value")
plt.colorbar(label= "bp")

for i in range(len(people)):
    plt.annotate(people[i], xy= (age[i],bp[i]), xytext=( age[i]+1,bp[i]+1))
plt.xlim(min(age), max(age)+10)
plt.ylim(min(bp), max(bp)+5)



plt.grid()

# %%
# Multiple Plots

cities = ["City A", "City B", "City C", "City D", "City E"]

# Winter: Temperature (℃) vs Humidity (%)
winter_temp = [5, 2, 10, 0, 7]
winter_humidity = [80, 75, 65, 85, 70]

# Summer: Temperature (℃) vs Humidity (%)
summer_temp = [25, 30, 28, 35, 27]
summer_humidity = [60, 50, 55, 45, 65]

# %%
plt.title("winter vs summer data")
plt.xlabel("temperature")
plt.ylabel("humidility")


plt.scatter(winter_temp,winter_humidity,label= "winter data",color = "blue")
plt.scatter(summer_temp,summer_humidity,label= "summer data",color = "red")
plt.legend()

# %%
# Pie Charts
expenses = ["Salaries", "Rent", "Marketing", "R&D", "Miscellaneous"]
amounts = [500, 150, 120, 100, 50]

# %%
explode = [0,0,0,0.2,0]
plt.pie(amounts  , labels = expenses, autopct="%1.1f%%",wedgeprops={
    "edgecolor":"black",
    "linewidth" : 2,
    "linestyle" : "--",
    # "alpha": 0.8,
    # "fill": False
},explode = explode, 
        startangle= 180,
        shadow = True
)

# plt.style.available


plt.style.use("default")
